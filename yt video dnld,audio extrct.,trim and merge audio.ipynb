# %%
# !pip install pafy
# !pip install youtube_dl
import youtube_dl
urls=['https://youtu.be/AZWZJripc0U']
ydl_opts = {}
for url in urls:
 with youtube_dl.YoutubeDL(ydl_opts) as ydl:
    ydl.download([url])
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.9 MB 5.2 MB/s
# ...
# [youtube] AZWZJripc0U: Downloading webpage
# [youtube] AZWZJripc0U: Downloading player 0e7373c2
# WARNING: Requested formats are incompatible for merge and will be merged into mkv.
# [download] Destination: Wedding Special _ Wedding Dances_ Say Na Say _ Salaa-e-ishq_ Mauja hi mauja _ NachleVe-AZWZJripc0U.f313.webm
# [download] 100% of 181.22MiB in 46:34
# [download] Destination: Wedding Special _ Wedding Dances_ Say Na Say _ Salaa-e-ishq_ Mauja hi mauja _ NachleVe-AZWZJripc0U.f140.m4a
# [download] 100% of 1.69MiB in 00:26
# [ffmpeg] Merging formats into "Wedding Special _ Wedding Dances_ Say Na Say _ Salaa-e-ishq_ Mauja hi mauja _ NachleVe-AZWZJripc0U.mkv"
# ...

# %%
import moviepy.editor

#video_paths=['/content/Jalebi Baby_ Genda Phool _ LCD Choreography _ Tesher _ Jacqueline Fernandez _ Badshah -NrXtn00uvqY.mp4']

video = moviepy.editor.VideoFileClip("/content/Wedding Special _ Wedding Dances_ Say Na Say _ Salaa-e-ishq_ Mauja hi mauja _ NachleVe-AZWZJripc0U.mkv")
audio = video.audio
audio.write_audiofile("file1.mp3")
# Out:
# [MoviePy] Writing audio in file1.mp3
# 100%|██████████| 2416/2416 [00:03<00:00, 701.56it/s]
# [MoviePy] Done.

# %%
# !pip install pydub
from pydub import AudioSegment
#importing file from location by giving its path
sound = AudioSegment.from_mp3("/content/file1.mp3")
#Selecting Portion we want to cut
StrtMin = 1
StrtSec = 6
EndMin = 1
EndSec = 45
# Time to milliseconds conversion
StrtTime = StrtMin*60*1000+StrtSec*1000
EndTime = EndMin*60*1000+EndSec*1000
# Opening file and extracting portion of it
extract = sound[StrtTime:EndTime]
# Saving file in required location
extract.export("extracted audio mauja.mp3", format="mp3")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# <_io.BufferedRandom name='extracted audio mauja.mp3'>

# %%
from pydub import AudioSegment

sound1 = AudioSegment.from_mp3("/content/extracted audio desi girl.mp3")
sound2 = AudioSegment.from_mp3("/content/extracted audio mauja.mp3")
sound3 = AudioSegment.from_mp3("/content/extracted audio jalebi baby.mp3")
combined_sounds = sound3 + sound1 + sound2
combined_sounds.export("final.mp3", format="mp3")
# Out:
# <_io.BufferedRandom name='final.mp3'>
